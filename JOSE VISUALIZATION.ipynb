# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_excel ("NORMAL_DATA.xlsx" )
df
# Out:
#          DATE          A          B          C          D
# 0  2000-01-01  10.858651   9.575365  10.554732   8.748169
# 1  2000-01-02  11.841476   8.523456   9.043647  10.796908
# 2  2000-01-03  10.822944   9.087180  11.079441  10.132836
# 3  2000-01-04  10.775548   8.530734   9.052745  10.663304
# 4  2000-01-05   8.921295   8.811509  11.803780  10.625011
# 5  2000-01-06  11.162709   9.784253  11.493744  10.422340
# 6  2000-01-07   9.890576  11.799419   9.446769   9.706728
# 7  2000-01-08  10.488684   9.982739  10.245826  10.089649
# 8  2000-01-09   7.424100   9.674851   7.972561   8.105548
# 9  2000-01-10  10.287375   8.564592  10.127814  10.199817
# 10 2000-01-11  12.060718   9.958814   9.484432   9.501033
# 11 2000-01-12   9.688538  10.460321   9.503259   9.431785
# 12 2000-01-13   9.661555  11.174404   8.504296   8.965641
# 13 2000-01-14  11.211608  11.553114   9.487774   9.778803
# 14 2000-01-15   8.742986   9.347363   9.114136   9.542776
# ...

# %%
df.set_index ( "DATE" , inplace=True )
df
# Out:
#                     A          B          C          D
# DATE
# 2000-01-01  10.858651   9.575365  10.554732   8.748169
# 2000-01-02  11.841476   8.523456   9.043647  10.796908
# 2000-01-03  10.822944   9.087180  11.079441  10.132836
# 2000-01-04  10.775548   8.530734   9.052745  10.663304
# 2000-01-05   8.921295   8.811509  11.803780  10.625011
# 2000-01-06  11.162709   9.784253  11.493744  10.422340
# 2000-01-07   9.890576  11.799419   9.446769   9.706728
# 2000-01-08  10.488684   9.982739  10.245826  10.089649
# 2000-01-09   7.424100   9.674851   7.972561   8.105548
# 2000-01-10  10.287375   8.564592  10.127814  10.199817
# 2000-01-11  12.060718   9.958814   9.484432   9.501033
# 2000-01-12   9.688538  10.460321   9.503259   9.431785
# 2000-01-13   9.661555  11.174404   8.504296   8.965641
# 2000-01-14  11.211608  11.553114   9.487774   9.778803
# 2000-01-15   8.742986   9.347363   9.114136   9.542776
# 2000-01-16  12.151215  10.732175  10.337928   9.603539
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#                '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#                '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#                '2000-02-18', '2000-02-19'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
df["A"].hist()
# Out:
# <Axes: >

# %%
df["A"].hist ( bins=8 )
# Out:
# <Axes: >

# %%
df["A"].plot ( kind="hist" , bins=8 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["A"].plot.hist ( bins=8 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: xlabel='DATE'>

# %%
df.plot.area ( alpha=0.64 )
# Out:
# <Axes: xlabel='DATE'>

# %%
df.plot.bar ( figsize=(9.6,4) )
# Out:
# <Axes: xlabel='DATE'>

# %%
df[["A","B","C","D"]]. plot.bar ( stacked=True , figsize=(9.6,4) )
# Out:
# <Axes: xlabel='DATE'>

# %%
df.reset_index ( inplace=True )
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.plot.line ( x="DATE" , y="B" )
# Out:
# <Axes: xlabel='DATE'>

# %%
df.plot.line ( x="DATE" , y="B" , figsize=(8.4,3) , lw=2 )
# Out:
# <Axes: xlabel='DATE'>

# %%
df.plot.scatter ( x="A" , y="B" )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter ( x="A" , y="B" , c="C" )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter ( x="A" , y="B" , c="C" , cmap="plasma" )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter ( x="A" , y="B" , s=df["C"] )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot.scatter ( x="A" , y="B" , s=df["C"]*16 )
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.set_index ( "DATE" , inplace=True )
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#                '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#                '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#                '2000-02-18', '2000-02-19'],
#               dtype='datetime64[ns]', name='DATE', freq=None)

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
new_data = np.random.randn (1000,2) 
new_df = pd.DataFrame ( new_data , columns=["E","F"] )
new_df
# Out:
#             E         F
# 0    1.488171  0.323151
# 1   -0.660533  1.299121
# 2   -1.062747  1.425333
# 3   -2.104137 -0.167526
# 4   -0.005926  1.736883
# ..        ...       ...
# 995 -0.571834  0.218692
# 996 -0.657287  0.173081
# 997 -0.812094  0.923016
# 998  0.588134  1.666941
# 999 -0.021223  0.528255
#
# [1000 rows x 2 columns]

# %%
new_df.plot.hexbin ( x="E" , y="F" )
# Out:
# <Axes: xlabel='E', ylabel='F'>

# %%
new_df.plot.hexbin ( x="E" , y="F" , gridsize=30 )
# Out:
# <Axes: xlabel='E', ylabel='F'>

# %%
new_df.plot.hexbin ( x="E" , y="F" , gridsize=20 )
# Out:
# <Axes: xlabel='E', ylabel='F'>

# %%
new_df.plot.hexbin ( x="E" , y="F" , gridsize=20 , cmap="plasma" )
# Out:
# <Axes: xlabel='E', ylabel='F'>

# %%
new_df.plot.hexbin ( x="E" , y="F" , gridsize=30 , cmap="plasma" )
# Out:
# <Axes: xlabel='E', ylabel='F'>

# %%
new_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
new_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
new_df["E"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
ex_data = np.random.random(2000).reshape(500,4)
ex_df = pd.DataFrame ( ex_data , columns=["G","H","K","L"] )
ex_df
# Out:
#             G         H         K         L
# 0    0.888683  0.450036  0.276549  0.005720
# 1    0.476386  0.587631  0.447099  0.004643
# 2    0.778789  0.939946  0.840892  0.591016
# 3    0.933500  0.402864  0.340231  0.374950
# 4    0.340921  0.831015  0.447407  0.648162
# ..        ...       ...       ...       ...
# 495  0.993848  0.794776  0.367471  0.439007
# 496  0.052614  0.077580  0.800926  0.312221
# 497  0.346670  0.109514  0.722904  0.523703
# 498  0.512951  0.709139  0.377629  0.863980
# 499  0.867990  0.379241  0.888507  0.270499
#
# [500 rows x 4 columns]

# %%
ex_df.plot.scatter ( x="G" , y="H" )
# Out:
# <Axes: xlabel='G', ylabel='H'>

# %%
ex_df.plot.scatter ( x="G" , y="H" , s=40 )
# Out:
# <Axes: xlabel='G', ylabel='H'>

# %%
ex_df.plot.scatter ( x="G" , y="H" , s=40 , c="brown" )
# Out:
# <Axes: xlabel='G', ylabel='H'>

# %%
ex_df.plot.scatter ( x="G" , y="H" , s=40 , c="brown" , figsize=(4,4) )
# Out:
# <Axes: xlabel='G', ylabel='H'>

# %%
ex_df["K"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
ex_df["K"].plot.hist ( bins=20 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use ("ggplot")
ex_df["K"].plot.hist ( bins=20 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
ex_df["K"].plot.hist ( bins=20 , alpha=0.72 )
# Out:
# <Axes: ylabel='Frequency'>

# %%
ex_df [[ "K" , "L" ]] .plot.box()
# Out:
# <Axes: >

# %%
ex_df["L"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
ex_df["L"].plot.kde ( lw=3.6 , ls="--" )
# Out:
# <Axes: ylabel='Density'>

# %%
ex_df["L"].plot.density ( lw=3.6 , ls="--" )
# Out:
# <Axes: ylabel='Density'>

# %%
ex_df.plot.area()
# Out:
# <Axes: >

# %%
ex_df[0:30]
# Out:
#            G         H         K         L
# 0   0.888683  0.450036  0.276549  0.005720
# 1   0.476386  0.587631  0.447099  0.004643
# 2   0.778789  0.939946  0.840892  0.591016
# 3   0.933500  0.402864  0.340231  0.374950
# 4   0.340921  0.831015  0.447407  0.648162
# 5   0.721746  0.210849  0.772408  0.251317
# 6   0.765396  0.161117  0.835898  0.411426
# 7   0.627359  0.987792  0.974675  0.538572
# 8   0.563946  0.509137  0.559839  0.173494
# 9   0.153242  0.013221  0.997762  0.000712
# 10  0.595481  0.492566  0.137880  0.860445
# 11  0.171740  0.989963  0.694168  0.915243
# 12  0.631555  0.900305  0.854357  0.990893
# 13  0.048897  0.487652  0.539977  0.296243
# 14  0.981334  0.309338  0.427381  0.980375
# 15  0.438284  0.521108  0.348738  0.124295
# 16  0.943338  0.526886  0.452530  0.925418
# 17  0.331827  0.704447  0.925286  0.682593
# 18  0.546108  0.457753  0.775687  0.072352
# 19  0.532682  0.507407  0.860007  0.818866
# 20  0.491936  0.396318  0.441400  0.576127
# ...

# %%
ex_df[0:30].plot.area()
# Out:
# <Axes: >

# %%
ex_df[0:30].plot.area ( alpha=0.56 )
# Out:
# <Axes: >

# %%
ex_df[0:30].plot.area ( alpha=0.56 )
plt.legend ( loc="center left" , bbox_to_anchor=(1.0,0.5) )

# %%
ex_df[0:30].plot.area ( alpha=0.80 )
plt.legend ( loc="center left" , bbox_to_anchor=(1.0,0.5) )

# %%
ex_df[0:60].plot.area ( alpha=0.80 )
plt.legend ( loc="center left" , bbox_to_anchor=(1.0,0.5) )

# %%
df = pd.read_excel ("NORMAL_DATA.xlsx" , index_col=0 )
df
# Out:
#                     A          B          C          D
# DATE
# 2000-01-01  10.858651   9.575365  10.554732   8.748169
# 2000-01-02  11.841476   8.523456   9.043647  10.796908
# 2000-01-03  10.822944   9.087180  11.079441  10.132836
# 2000-01-04  10.775548   8.530734   9.052745  10.663304
# 2000-01-05   8.921295   8.811509  11.803780  10.625011
# 2000-01-06  11.162709   9.784253  11.493744  10.422340
# 2000-01-07   9.890576  11.799419   9.446769   9.706728
# 2000-01-08  10.488684   9.982739  10.245826  10.089649
# 2000-01-09   7.424100   9.674851   7.972561   8.105548
# 2000-01-10  10.287375   8.564592  10.127814  10.199817
# 2000-01-11  12.060718   9.958814   9.484432   9.501033
# 2000-01-12   9.688538  10.460321   9.503259   9.431785
# 2000-01-13   9.661555  11.174404   8.504296   8.965641
# 2000-01-14  11.211608  11.553114   9.487774   9.778803
# 2000-01-15   8.742986   9.347363   9.114136   9.542776
# 2000-01-16  12.151215  10.732175  10.337928   9.603539
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#                '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#                '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#                '2000-02-18', '2000-02-19'],
#               dtype='datetime64[ns]', name='DATE', freq=None)
