# %%
import pandas as pd
sal = pd.read_excel ( "SALARY_DATA.xlsx" )
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651            NO DATA
# 148651  148652            NO DATA
# 148652  148653            NO DATA
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651        NO DATA                     NO DATA      NaN
# 148651  148652        NO DATA                     NO DATA      NaN
# 148652  148653        NO DATA                     NO DATA      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
sal.info()
"THE INFORMATION OF DATASET IS GIVEN ABOVE"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB
# 'THE INFORMATION OF DATASET IS GIVEN ABOVE'

# %%
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
sal["BasePay"].mean()
# Out:
# 66325.4488404877

# %%
sal["OvertimePay"].max()
# Out:
# 245131.88

# %%
sal["OvertimePay"].min()
# Out:
# -0.01

# %%
sal [ sal["EmployeeName"] == "JOSEPH DRISCOLL" ]
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
sal [ sal["EmployeeName"] == "JOSEPH DRISCOLL" ] ["JobTitle"]
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal [ sal["EmployeeName"] == "JOSEPH DRISCOLL" ] ["TotalPayBenefits"]
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal [ sal["EmployeeName"] == "Joseph Driscoll" ] ["TotalPayBenefits"]
# Out:
# 36198    331834.79
# Name: TotalPayBenefits, dtype: float64

# %%
sal["TotalPayBenefits"].max()
# Out:
# 567595.43

# %%
sal [ sal["TotalPayBenefits"].max() == sal["TotalPayBenefits"] ]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal [ sal["TotalPayBenefits"].max() == sal["TotalPayBenefits"] ] ["EmployeeName"]
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
sal.loc [ sal["TotalPayBenefits"].idxmax() ]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal["TotalPayBenefits"].idxmax()
# Out:
# 0

# %%
sal["TotalPayBenefits"].argmax()
# Out:
# 0

# %%
sal.iloc [ sal["TotalPayBenefits"].argmax() ]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal.loc [ sal["TotalPayBenefits"].argmax() ]
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
sal [ sal["TotalPayBenefits"].min() == sal["TotalPayBenefits"] ]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
sal.groupby ("Year") .mean()
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_7768\9073638.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sal.groupby ("Year") .mean()
#             Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.0  63595.956517  4531.065429  3617.081926           NaN
# 2012   54542.5  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91728.5  69630.030216  5281.641980  3819.969007  23829.076572
# 2014  129593.0  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits  Notes  Status
# Year
# 2011  71744.103871      71744.103871    NaN     NaN
# 2012  74113.262265     100553.229232    NaN     NaN
# 2013  77611.443142     101440.519714    NaN     NaN
# 2014  75463.918140     100250.918884    NaN     NaN

# %%
sal.groupby ("Year") .mean() ["BasePay"]
# Out:
# C:\Users\ARPIT-MIMANI\AppData\Local\Temp\ipykernel_7768\1903661938.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sal.groupby ("Year") .mean() ["BasePay"]
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal.groupby ("Year") ["BasePay"] .mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'NO DATA'], dtype=object)

# %%
sal["JobTitle"].nunique()
# Out:
# 2159

# %%
sal["JobTitle"].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
sal["JobTitle"].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sal [ sal["Year"] == 2013 ] ["JobTitle"] .value_counts()
# Out:
# Transit Operator                  2295
# Special Nurse                     1445
# Registered Nurse                  1231
# Public Svc Aide-Public Works       859
# Custodian                          789
#                                   ...
# Sr General Utility Mechanic          1
# Sprv Adult Prob Ofc (SFERS)          1
# Mayoral Staff XII                    1
# Pr Investigator, Tax Collector       1
# Senior Assessment Clerk              1
# Name: JobTitle, Length: 1051, dtype: int64

# %%
sal [ sal["Year"] == 2013 ] ["JobTitle"] .value_counts() == 1
# Out:
# Transit Operator                  False
# Special Nurse                     False
# Registered Nurse                  False
# Public Svc Aide-Public Works      False
# Custodian                         False
#                                   ...
# Sr General Utility Mechanic        True
# Sprv Adult Prob Ofc (SFERS)        True
# Mayoral Staff XII                  True
# Pr Investigator, Tax Collector     True
# Senior Assessment Clerk            True
# Name: JobTitle, Length: 1051, dtype: bool

# %%
sum ( sal [ sal["Year"] == 2013 ] ["JobTitle"] .value_counts() == 1 )
# Out:
# 202

# %%
sal["JobTitle"]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                           NO DATA
# 148651                                           NO DATA
# 148652                                           NO DATA
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
sal["JobTitle"].iloc[0]
# Out:
# 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'

# %%
def chief_string ( title ) :
    if "chief" in title.lower().split() :
        return True
    else :
        return False
    
chief_string ( "GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY" )
# Out:
# False

# %%
chief_string ( "CHIEF MANAGER-METROPOLITAN TRANSIT AUTHORITY" )
# Out:
# True

# %%
sal ["JobTitle"] .apply ( lambda x : chief_string(x) )
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
sum ( sal ["JobTitle"] .apply ( lambda x : chief_string(x) ) )
# Out:
# 477

# %%
sal["TitleLen"] = sal["JobTitle"] .apply (len)
sal["TitleLen"]
# Out:
# 0         46
# 1         31
# 2         31
# 3         36
# 4         44
#           ..
# 148649     9
# 148650     7
# 148651     7
# 148652     7
# 148653    26
# Name: TitleLen, Length: 148654, dtype: int64

# %%
sal [[ "JobTitle" , "TitleLen" ]]
# Out:
#                                               JobTitle  TitleLen
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY        46
# 1                      CAPTAIN III (POLICE DEPARTMENT)        31
# 2                      CAPTAIN III (POLICE DEPARTMENT)        31
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC        36
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)        44
# ...                                                ...       ...
# 148649                                       Custodian         9
# 148650                                         NO DATA         7
# 148651                                         NO DATA         7
# 148652                                         NO DATA         7
# 148653                      Counselor, Log Cabin Ranch        26
#
# [148654 rows x 2 columns]

# %%
sal [[ "TotalPayBenefits" , "TitleLen" ]]
# Out:
#         TotalPayBenefits  TitleLen
# 0              567595.43        46
# 1              538909.28        31
# 2              335279.91        31
# 3              332343.61        36
# 4              326373.19        44
# ...                  ...       ...
# 148649              0.00         9
# 148650              0.00         7
# 148651              0.00         7
# 148652              0.00         7
# 148653           -618.13        26
#
# [148654 rows x 2 columns]

# %%
sal [[ "TotalPayBenefits" , "TitleLen" ]] .corr()
# Out:
#                   TotalPayBenefits  TitleLen
# TotalPayBenefits           1.00000  -0.03685
# TitleLen                  -0.03685   1.00000

# %%
sal.shape
# Out:
# (148654, 14)

# %%
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status', 'TitleLen'],
#       dtype='object')

# %%
sal.shape
# Out:
# (148654, 14)

# %%
ecom = pd.read_excel ("ECOMMERCE_DATA.xlsx")
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123400  2020-02-01
# 1  Fletcher, Richards and Whitaker  3337758169645350  2018-11-01
# ...

# %%
ecom.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701  2022-03-01
# 9996  Hale, Collins and Wilson   210033169205009  2025-07-01
# ...

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len ( ecom.columns )
# Out:
# 14

# %%
ecom.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
len ( ecom.index )
# Out:
# 10000

# %%
ecom.info()
"THE INFORMATION OF DATASET IS GIVEN ABOVE"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  datetime64[ns]
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 1.1+ MB
# ...

# %%
ecom["Purchase Price"].mean()
# Out:
# 50.347302

# %%
ecom["Purchase Price"].max()
# Out:
# 99.99

# %%
ecom["Purchase Price"].min()
# Out:
# 0.0

# %%
ecom [ ecom["Language"] == "en" ]
# Out:
#                                                 Address    Lot AM or PM  \
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# ...                                                 ...    ...      ...
# 9961        714 Joshua Ridges\nCarpenterville, NJ 37418  84 rK       PM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  04 QN       PM
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  69 XK       PM
#
#                                            Browser Info  \
# ...

# %%
ecom [ ecom["Language"] == "en" ] .count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
ecom [ ecom["Language"] == "en" ] ["Language"] .count()
# Out:
# 1098

# %%
ecom [ ecom["Job"] == "Lawyer" ] .info()
"GET THE NUMBER OF JOB TITLE AS LAWYER"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           30 non-null     object
#  1   Lot               30 non-null     object
#  2   AM or PM          30 non-null     object
#  3   Browser Info      30 non-null     object
#  4   Company           30 non-null     object
#  5   Credit Card       30 non-null     int64
#  6   CC Exp Date       30 non-null     datetime64[ns]
#  7   CC Security Code  30 non-null     int64
#  8   CC Provider       30 non-null     object
#  9   Email             30 non-null     object
#  10  Job               30 non-null     object
#  11  IP Address        30 non-null     object
#  12  Language          30 non-null     object
#  13  Purchase Price    30 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(10)
# memory usage: 3.5+ KB
# ...

# %%
ecom [ ecom["Job"] == "Lawyer" ] .count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
ecom [ ecom["Job"] == "Lawyer" ] .index
# Out:
# Int64Index([ 470,  508, 1275, 1569, 1682, 2164, 2619, 2935, 3663, 3738, 3966,
#             5053, 5339, 5452, 5562, 5974, 6131, 6136, 6220, 7368, 7645, 8127,
#             8220, 8620, 8683, 8801, 8860, 9175, 9659, 9979],
#            dtype='int64')

# %%
len ( ecom [ ecom["Job"] == "Lawyer" ] .index )
# Out:
# 30

# %%
ecom["AM or PM"].unique()
# Out:
# array(['PM', 'AM'], dtype=object)

# %%
ecom["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
ecom["Job"].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
ecom["Job"].value_counts().head(10)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Purchasing manager                   27
# Designer, jewellery                  27
# Research officer, political party    27
# Charity fundraiser                   26
# Designer, fashion/clothing           26
# Social worker                        26
# Dietitian                            26
# Name: Job, dtype: int64

# %%
ecom [ ecom["Lot"] == "90 WT" ]
# Out:
#                                                Address    Lot AM or PM  \
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  90 WT       AM
#
#                                           Browser Info     Company  \
# 513  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like M...  Bright PLC
#
#       Credit Card CC Exp Date  CC Security Code       CC Provider  \
# 513  630438419693  2019-11-01               173  American Express
#
#                 Email              Job     IP Address Language  Purchase Price
# 513  jesse00@page.net  Energy engineer  156.70.208.94       ru            75.1

# %%
ecom [ ecom["Lot"] == "90 WT" ] ["Purchase Price"]
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom [ ecom["Credit Card"] == 4926535242672850 ]
# Out:
#                                                 Address    Lot AM or PM  \
# 1234  2470 Maria Manors Suite 185\nJoneshaven, MN 87251  82 UX       PM
#
#                                            Browser Info  \
# 1234  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...
#
#                     Company       Credit Card CC Exp Date  CC Security Code  \
# 1234  Cole, King and Bowers  4926535242672850  2021-09-01               188
#
#            CC Provider                         Email  \
# 1234  American Express  bondellen@williams-garza.com
#
#                                     Job    IP Address Language  Purchase Price
# 1234  Planning and development surveyor  159.182.3.50       ru           77.88

# %%
ecom [ ecom["Credit Card"] == 4926535242672850 ] ["Email"]
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
ecom [ ( ecom["CC Provider"] == "American Express" ) & ( ecom["Purchase Price"] > 95 ) ]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %%
ecom [ ( ecom["CC Provider"] == "American Express" ) & ( ecom["Purchase Price"] > 95 ) ] .count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
len ( ecom [ ( ecom["CC Provider"] == "American Express" ) & ( ecom["Purchase Price"] > 95 ) ] .index )
# Out:
# 39

# %%
ecom["Year"] = ecom["CC Exp Date"].dt.year
ecom["Year"]
# Out:
# 0       2020
# 1       2018
# 2       2019
# 3       2024
# 4       2025
#         ...
# 9995    2022
# 9996    2025
# 9997    2021
# 9998    2017
# 9999    2019
# Name: Year, Length: 10000, dtype: int64

# %%
ecom [ ecom["Year"] == 2025 ]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
ecom [ ecom["Year"] == 2025 ] .count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# Year                1033
# dtype: int64

# %%
ecom [ ecom["Year"] == 2025 ] ["Year"] .count()
# Out:
# 1033

# %%
example_email =  ecom["Email"].iloc[0]
example_email
# Out:
# 'pdunlap@yahoo.com'

# %%
example_email.split("@")
# Out:
# ['pdunlap', 'yahoo.com']

# %%
example_email.split("@")[1]
# Out:
# 'yahoo.com'

# %%
ecom["Email"] .apply ( lambda email_id : email_id.split("@")[1] )
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
ecom["Email"] .apply ( lambda email_id : email_id.split("@")[1] ) .value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: Email, Length: 3416, dtype: int64

# %%
ecom["Email"] .apply ( lambda email_id : email_id.split("@")[1] ) .value_counts() .head(10)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# brown.com         29
# johnson.com       29
# davis.com         25
# jones.com         25
# martinez.com      19
# Name: Email, dtype: int64

# %%
ecom.shape
# Out:
# (10000, 15)
